# %%
import nltk
import tweepy
import sys
import os
import json
from nltk.corpus import stopwords
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
#from twitterapistuff import *
from retrying import retry
import pandas as pd

# %%
#consumer key, consumer secret, access token, access secret.

ckey="t7mlx9A9aFHrOR91SvmmHI8I4"
csecret="4HQFjD4p921xcI2AZQ2mnqxXkI4GnmllkaldXITl8XPV8hy4fb"
atoken="927974990607208449-KcVvOqRaXvFqgmsMoeoheCRw0LhZm71"
asecret="IgR6Q5tZxbdbvbMIL9WzgAv6eSV2uvlKuLXICJe9XmGFG"

# %%
class listener(StreamListener):

    def on_status(self, status):
        if status.retweeted_status:
            return
        print(status.text)

    def on_error(self, status_code):
        if status_code == 420:
            return False

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

Stream = Stream(auth, listener())
Stream.filter(track=["brexit"])

# %%
'''
class listener(StreamListener):

    def on_data(self, data):
        #print(data)
        return(True)

    def on_error(self, status):
        print status

auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)

Stream = Stream(auth, listener())
Stream.filter(track=["brexit"])

'''

# %%
description = status.user.description              #User bio
loc = status.user.location                         #User location
text = status.text                                 #Tweet
coords = status.coordinates                        #Tweet's co-ordinates
name = status.user.screen_name                     #User screen name
user_created = status.user.created_at              #When user's account was created
followers = status.user.followers_count            #Number of followers of the user
id_str = status.id_str                             #Unique ID assigned by Twitter to the tweet
created = status.created_at                        #When the tweet was sent
retweets = status.retweet_count                    #Number of times tweet has been retweeted
bg_color = status.user.profile_background_color    #Background color chosen by the user for their profile pic

# %%
Dict = {'description': description, 'loc': loc, 'text': text, 'coords': coords, 'name': name, 'user_created': user_created, 'followers': followers, 'id_str': id_str, 'created': created, 'retweets': retweets, 'bg_color': bg_color}

with open('Tweets1.txt', 'w') as file:
     file.write(json.dumps(Dict))

# %%
#df = pd.read_csv('Tweets.txt', error_bad_lines = False, header = None)
df = pd.read_csv('Tweets.txt', error_bad_lines = False, header = None)
# Out:
# b'Skipping line 7: expected 142 fields, saw 165\nSkipping line 9: expected 142 fields, saw 164\nSkipping line 11: expected 142 fields, saw 305\nSkipping line 13: expected 142 fields, saw 149\nSkipping line 15: expected 142 fields, saw 162\nSkipping line 17: expected 142 fields, saw 162\nSkipping line 19: expected 142 fields, saw 159\nSkipping line 21: expected 142 fields, saw 157\nSkipping line 23: expected 142 fields, saw 164\nSkipping line 25: expected 142 fields, saw 178\nSkipping line 27: expected 142 fields, saw 305\nSkipping line 29: expected 142 fields, saw 181\nSkipping line 31: expected 142 fields, saw 347\nSkipping line 33: expected 142 fields, saw 355\nSkipping line 35: expected 142 fields, saw 176\nSkipping line 39: expected 142 fields, saw 150\nSkipping line 41: expected 142 fields, saw 159\nSkipping line 43: expected 142 fields, saw 208\nSkipping line 45: expected 142 fields, saw 159\nSkipping line 47: expected 142 fields, saw 319\nSkipping line 49: expected 142 fields,
# ...

# %%
df
# Out:
#                                                   0                      1    \
# 0      {"created_at":"Wed Jan 03 16:22:57 +0000 2018"  id:948590513988521987
# 1      {"created_at":"Wed Jan 03 16:22:57 +0000 2018"  id:948590516182093825
# 2      {"created_at":"Wed Jan 03 16:22:58 +0000 2018"  id:948590519629828096
# 3      {"created_at":"Wed Jan 03 16:23:04 +0000 2018"  id:948590545470967809
# 4      {"created_at":"Wed Jan 03 16:23:12 +0000 2018"  id:948590580006866944
# 5      {"created_at":"Wed Jan 03 16:23:15 +0000 2018"  id:948590591587254273
# 6      {"created_at":"Wed Jan 03 16:23:15 +0000 2018"  id:948590591436361728
# 7      {"created_at":"Wed Jan 03 16:23:21 +0000 2018"  id:948590614832087041
# 8      {"created_at":"Wed Jan 03 16:23:21 +0000 2018"  id:948590617386504192
# 9      {"created_at":"Wed Jan 03 16:23:24 +0000 2018"  id:948590626953748481
# 10     {"created_at":"Wed Jan 03 16:23:24 +0000 2018"  id:948590628413337600
# ...
